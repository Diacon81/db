# %% [markdown]
# # Databases. Individual project by Ainhoa.
#
# ## This project consists in the practice of 29 exercises using the graphical interface of mongoDB Compass, as it is very intuitive and facilitates the work with the same result if we use MongoDB Shell.
#
# ### The databases is called "music_db" and its three collections: "music_db.songs", "music_db.artists" and "music_db.albums".
#
# #### The fields, are:
#
# #### Fields (Collection: artists): _id (ObjectID), name (string), genre (string).
#
# #### Fields (Collection: albums): _id (ObjectID), title (string), release_year (number), artist_id (ObjectID)
#
# #### Fields (Collection: songs): _id (ObjectID), title (string), duration (number), album_id (ObjectID)
#
# #### Exercises:
#
# #### Using the Collection: artist.
#
# #### 1. Insert a new artist into the database ("John Doe" and genre "Rock")
#
# #### 2. Insert a new artist with their genre ("Taylor Swift" and genre "Pop")
#
# #### 3. Insert multiple artists with their genres ("Ed Sheeran" with the genre "Pop" and another for "Drake" with the genre "Hip Hop")
#
# #### 4. Insert an artist ("Adele") without specifying the genre
#
# #### 5. Insert a new artist and update their genre ("Kendrick Lamar" without a specified genre initially. Then, it will be updated to include the genre "Hip Hop")
#
# #### 6. Find all artists of a specific genre ("Pop")
#
# #### 7. Update the genre of an artist ("John Doe" with the updated genre)
#
# #### 8. Update the genre of all artists of a specific id
#
# #### 9. Delete an artist  ("John Doe") and their associated albums and songs

# %% [markdown]
# #### '![Development] (artists.jpg)'

# %% [markdown]
# ![artists.jpg](attachment:artists.jpg)

# %% [markdown]
# #### Result

# %%
import pandas as pd
# Load JSON file into a DataFrame
df = pd.read_json('music_db.artists.json')
# Display the DataFrame
print(df)
# Out:
#             _id            name    genre
# 0    artist2_id    Taylor Swift      Pop
# 1  artist3.1_id      Ed Sheeran      Pop
# 2  artist3.2_id           Drake  Hip Hop
# 3    artist4_id           Adele     None
# 4    artist5_id  Kendrick Lamar  Hip Hop

# %% [markdown]
# #### Using the Collection: albums.
#
# #### 10. Insert a new album "1989" released in 2014, associated with the specified artist ObjectID.
#
# #### 11. Insert multiple albums "÷" (released in 2017) and "Views" (released in 2016), both associated with the specified artist ObjectID.
#
# #### 12. Insert an album with a specific ObjectID and reference an existing artist for "Lemonade" (released in 2016), associated with the specified artist ObjectID of Beyoncé.
#
# #### 13. Insert an album wih no reference to any artist for the album "Untitled Album" released in 2023.
#
# #### 14. Insert a new album
#
# #### 15. Update an album´s release year (the album "Thriller" with the updated release year 1982)
#
# #### 16. Insert a new album for an existing artist with the artist_id reference
#
# #### 17. Find all albums released after a given year (release_year after 2000)
#
# #### 18. Increment the release year of all albums released before 2000 by 5 years.

# %% [markdown]
# #### '![Development] (albums.jpg)'

# %% [markdown]
# ![albums2.jpg](attachment:albums2.jpg)

# %% [markdown]
# #### Result

# %%
# Load JSON file into a DataFrame
df = pd.read_json('music_db.albums.json')
# Display the DataFrame
print(df)
# Out:
#            _id                    title  release_year   artist_id
# 0    album1_id                     1989        2014.0  artist6_id
# 1  album2.1_id                        ÷        2017.0  artist7_id
# 2  album2.2_id                    Views        2016.0  artist7_id
# 3    album3_id                 Lemonade        2016.0  artist8_id
# 4    album4_id           Untitled Album        2023.0        None
# 5    album5_id                      NaN           NaN         NaN
# 6    album9_id                 Thriller        1982.0  artist9_id
# 7   album10_id  Lemonade Deluxe Edition        2023.0  artist8_id

# %% [markdown]
# #### Using the Collection: songs.
#
# #### 19. Insert a new song ("Blank Space" with a duration of 231 seconds, associated with the specified album ObjectID)
#
# #### 20. Insert multiple songs (for the songs "Shape of You" with a duration of 234 seconds and "Hotline Bling" with a duration of 267 seconds). Both associated with the specified album ObjectID.
#
# #### 21. Insert a song ("Halo"), with a duration of 215 seconds y associated with the specified album ObjectID of Beyoncé´s album
#
# #### 22. Insert a song ("Single Song" with a duration of 180 seconds, without any reference to an album)
#
# #### 23. Insert a new song
#
# #### 24. Delete a song ("Bohemian Rhapsody" removed from the songs collection)
#
# #### 25. Find all songs of a particular albums (the album_id field to find all songs belonging to a specific artist)
#
# #### 26. Delete all songs from a specific album (remove all songs associated with that album_id)
#
# #### 27. Increment the duration of a specific song by 30 seconds
#
# #### 28. Insert multiple songs into an album (the songs "Song1", "Song2" and "Song3", all associated with the "New Album")
#
# #### 29. Find the song with the longest duration from the albums collection

# %% [markdown]
# #### '![Development] (songs.jpg)'

# %% [markdown]
# ![songs.jpg](attachment:songs.jpg)

# %% [markdown]
# #### Result

# %%
# Load JSON file into a DataFrame
df = pd.read_json('music_db.songs.json')
# Display the DataFrame
print(df)
# Out:
#         _id          title  duration    album_id
# 0  song1_id    Blank Space     231.0   album6_id
# 1  song3_id           Halo     245.0   album8_id
# 2  song4_id    Single Song     180.0        None
# 3  song5_id            NaN       NaN         NaN
# 4  song7_id  Untitled Song       0.0  album11_id
# 5  song8_id  Untitled Song       0.0  album11_id
# 6  song9_id  Untitled Song       0.0  album11_id

# %% [markdown]
# #### '![Final result] (music_db.jpg)'

# %% [markdown]
# ![music_db.jpg](attachment:music_db.jpg)
